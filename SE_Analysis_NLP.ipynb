# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhusree-dot/Data-science-Clustering-/blob/main/SE_Analysis_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from textblob.en import polarity
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer
import openpyxl
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')

# After mounting the device, use the following code to go to the folder of your choice:
def sentiment():

  for filename in os.listdir():
      if filename.endswith('.txt'):
          with open(filename, 'r') as f:
              text = f.read()

              blob = TextBlob(text)
              #blob.sentiment.polarity
              if  blob.sentiment.polarity < 0 :
                  senty = "Negative"
              elif blob.sentiment.polarity > 0:
                    senty = "Positive"

              results.append({'filename': filename, 'sentimental': senty})
              print(filename, ":" ,  blob.sentiment, "-", senty)

import os
os.chdir('/content/drive/MyDrive/txt_sentoken/pos')
workbook1 = openpyxl.Workbook()

sentiment()
df = pd.DataFrame(results)
df.to_csv('Natural Language Processing.csv',index=False)
print("---------------------------------------------------------------------------------------------------------------------------------------------------------")
os.chdir('/content/drive/MyDrive/txt_sentoken/neg')
workbook2 = openpyxl.Workbook()
results=[]
sentiment()
df = pd.DataFrame(results)
df.to_csv('Natural Language Processing1.csv',index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# cv000_29590.txt : Sentiment(polarity=0.02366334963737561, subjectivity=0.48609799291617484) - Positive
# cv001_18431.txt : Sentiment(polarity=0.103847233495671, subjectivity=0.5179203869047619) - Positive
# cv002_15918.txt : Sentiment(polarity=0.13109217171717172, subjectivity=0.5567358104858104) - Positive
# cv003_11664.txt : Sentiment(polarity=0.1106257682646571, subjectivity=0.4757288493399604) - Positive
# cv004_11636.txt : Sentiment(polarity=-0.07015070346320346, subjectivity=0.5166861471861471) - Negative
# cv005_29443.txt : Sentiment(polarity=0.12210534686341136, subjectivity=0.42703176154789063) - Positive
# cv006_15448.txt : Sentiment(polarity=0.11495892100730809, subjectivity=0.538592375366569) - Positive
# cv007_4968.txt : Sentiment(polarity=0.11924991674991678, subjectivity=0.49278055278055277) - Positive
# ...
